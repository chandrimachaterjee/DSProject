# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import mean_squared_error,mean_absolute_error

from sklearn.metrics import accuracy_score, confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('heartdisease_data.csv')
df
# Out:
#      63  1  4  140  260  0  1.1  112 1.2     3  2  ? ?.1  2.1
# 0    44  1  4  130  209  0    1  127   0     0  ?  ?   ?    0
# 1    60  1  4  132  218  0    1  140   1   1.5  3  ?   ?    2
# 2    55  1  4  142  228  0    1  149   1   2.5  1  ?   ?    1
# 3    66  1  3  110  213  1    2   99   1   1.3  2  ?   ?    0
# 4    66  1  3  120    0  0    1  120   0  -0.5  1  ?   ?    0
# ..   .. .. ..  ...  ... ..  ...  ...  ..   ... .. ..  ..  ...
# 194  54  0  4  127  333  1    1  154   0     0  ?  ?   ?    1
# 195  62  1  1    ?  139  0    1    ?   ?     ?  ?  ?   ?    0
# 196  55  1  4  122  223  1    1  100   0     0  ?  ?   6    2
# 197  58  1  4    ?  385  1    2    ?   ?     ?  ?  ?   ?    0
# 198  62  1  2  120  254  0    2   93   1     0  ?  ?   ?    1
#
# [199 rows x 14 columns]

# %%
columns=['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','num']

# %%
df=pd.read_csv('heartdisease_data.csv',names=columns, header=0)

df
# Out:
#      age  sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope ca  \
# 0     44    1   4      130  209   0        1     127     0       0     ?  ?
# 1     60    1   4      132  218   0        1     140     1     1.5     3  ?
# 2     55    1   4      142  228   0        1     149     1     2.5     1  ?
# 3     66    1   3      110  213   1        2      99     1     1.3     2  ?
# 4     66    1   3      120    0   0        1     120     0    -0.5     1  ?
# ..   ...  ...  ..      ...  ...  ..      ...     ...   ...     ...   ... ..
# 194   54    0   4      127  333   1        1     154     0       0     ?  ?
# 195   62    1   1        ?  139   0        1       ?     ?       ?     ?  ?
# 196   55    1   4      122  223   1        1     100     0       0     ?  ?
# 197   58    1   4        ?  385   1        2       ?     ?       ?     ?  ?
# 198   62    1   2      120  254   0        2      93     1       0     ?  ?
#
#     thal  num
# 0      ?    0
# 1      ?    2
# 2      ?    1
# 3      ?    0
# 4      ?    0
# ..   ...  ...
# 194    ?    1
# 195    ?    0
# 196    6    2
# 197    ?    0
# 198    ?    1
#
# [199 rows x 14 columns]

# %%
df=df.replace({'?':"nan"})

df
# Out:
#      age  sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope   ca  \
# 0     44    1   4      130  209   0        1     127     0       0   nan  nan
# 1     60    1   4      132  218   0        1     140     1     1.5     3  nan
# 2     55    1   4      142  228   0        1     149     1     2.5     1  nan
# 3     66    1   3      110  213   1        2      99     1     1.3     2  nan
# 4     66    1   3      120    0   0        1     120     0    -0.5     1  nan
# ..   ...  ...  ..      ...  ...  ..      ...     ...   ...     ...   ...  ...
# 194   54    0   4      127  333   1        1     154     0       0   nan  nan
# 195   62    1   1      nan  139   0        1     nan   nan     nan   nan  nan
# 196   55    1   4      122  223   1        1     100     0       0   nan  nan
# 197   58    1   4      nan  385   1        2     nan   nan     nan   nan  nan
# 198   62    1   2      120  254   0        2      93     1       0   nan  nan
#
#     thal  num
# 0    nan    0
# 1    nan    2
# 2    nan    1
# 3    nan    0
# 4    nan    0
# ..   ...  ...
# 194  nan    1
# 195  nan    0
# 196    6    2
# 197  nan    0
# 198  nan    1
#
# [199 rows x 14 columns]

# %%
df.dtypes
# Out:
# age          int64
# sex          int64
# cp           int64
# trestbps    object
# chol        object
# fbs         object
# restecg      int64
# thalach     object
# exang       object
# oldpeak     object
# slope       object
# ca          object
# thal        object
# num          int64
# dtype: object

# %% [markdown]
# Lets use LabelEncoder to convert all categorical data into numerical data, so that EDA could be done properly to undertand the dataset better

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
list1 = ['trestbps','chol','fbs','thalach','exang','oldpeak','slope','ca','thal']
for val in list1:
    df[val] = le.fit_transform(df[val].astype(str))

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     44    1   4        17    28    0        1       21      0        1
# 1     60    1   4        18    35    0        1       30      1        6
# 2     55    1   4        24    45    0        1       35      1       10
# 3     66    1   3         5    31    1        2       58      1        5
# 4     66    1   3        10     0    0        1       14      0        0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 194   54    0   4        15    91    1        1       38      0        1
# 195   62    1   1        40     2    0        1       59      2       14
# 196   55    1   4        11    40    1        1        0      0        1
# 197   58    1   4        40    97    1        2       59      2       14
# 198   62    1   2        10    59    0        2       53      1        1
#
#      slope  ca  thal  num
# 0        3   1     3    0
# 1        2   1     3    2
# 2        0   1     3    1
# 3        1   1     3    0
# 4        0   1     3    0
# ..     ...  ..   ...  ...
# 194      3   1     3    1
# 195      3   1     3    0
# 196      3   1     1    2
# 197      3   1     3    0
# 198      3   1     3    1
#
# [199 rows x 14 columns]

# %%
#Let's check the datatypes of the columns
df.dtypes
# Out:
# age         int64
# sex         int64
# cp          int64
# trestbps    int32
# chol        int32
# fbs         int32
# restecg     int64
# thalach     int32
# exang       int32
# oldpeak     int32
# slope       int32
# ca          int32
# thal        int32
# num         int64
# dtype: object

# %%
df=df.replace(np.nan,df.mean())

df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     44    1   4        17    28    0        1       21      0        1
# 1     60    1   4        18    35    0        1       30      1        6
# 2     55    1   4        24    45    0        1       35      1       10
# 3     66    1   3         5    31    1        2       58      1        5
# 4     66    1   3        10     0    0        1       14      0        0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 194   54    0   4        15    91    1        1       38      0        1
# 195   62    1   1        40     2    0        1       59      2       14
# 196   55    1   4        11    40    1        1        0      0        1
# 197   58    1   4        40    97    1        2       59      2       14
# 198   62    1   2        10    59    0        2       53      1        1
#
#      slope  ca  thal  num
# 0        3   1     3    0
# 1        2   1     3    2
# 2        0   1     3    1
# 3        1   1     3    0
# 4        0   1     3    0
# ..     ...  ..   ...  ...
# 194      3   1     3    1
# 195      3   1     3    0
# 196      3   1     1    2
# 197      3   1     3    0
# 198      3   1     3    1
#
# [199 rows x 14 columns]

# %%
df.shape
# Out:
# (199, 14)

# %%
#lets check no. of category for target variable.
df.num.unique()
# Out:
# array([0, 2, 1, 3, 4], dtype=int64)

# %%
df.num.value_counts()
# Out:
# 1    56
# 0    51
# 3    42
# 2    40
# 4    10
# Name: num, dtype: int64

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
#No null values is present.

# %%
#Lets check the count of each class in taret variables.
sns.countplot(x='num',data=df)
plt.show()

# %%
df.plot(kind ='box',subplots = True,layout=(2,7))
# Out:
# age            AxesSubplot(0.125,0.536818;0.0945122x0.343182)
# sex         AxesSubplot(0.238415,0.536818;0.0945122x0.343182)
# cp          AxesSubplot(0.351829,0.536818;0.0945122x0.343182)
# trestbps    AxesSubplot(0.465244,0.536818;0.0945122x0.343182)
# chol        AxesSubplot(0.578659,0.536818;0.0945122x0.343182)
# fbs         AxesSubplot(0.692073,0.536818;0.0945122x0.343182)
# restecg     AxesSubplot(0.805488,0.536818;0.0945122x0.343182)
# thalach           AxesSubplot(0.125,0.125;0.0945122x0.343182)
# exang          AxesSubplot(0.238415,0.125;0.0945122x0.343182)
# oldpeak        AxesSubplot(0.351829,0.125;0.0945122x0.343182)
# slope          AxesSubplot(0.465244,0.125;0.0945122x0.343182)
# ca             AxesSubplot(0.578659,0.125;0.0945122x0.343182)
# thal           AxesSubplot(0.692073,0.125;0.0945122x0.343182)
# num            AxesSubplot(0.805488,0.125;0.0945122x0.343182)
# dtype: object

# %%
sns.pairplot(df)

# %%
#Lets describe the matrix
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  199.000000  199.000000  199.000000  199.000000  199.000000  199.000000
# mean    59.331658    0.969849    3.502513   24.768844   37.532663    0.412060
# std      7.827080    0.171433    0.796928   12.570080   32.270600    0.560533
# min     35.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     55.000000    1.000000    3.000000   14.000000    1.500000    0.000000
# 50%     60.000000    1.000000    4.000000   24.000000   34.000000    0.000000
# 75%     64.000000    1.000000    4.000000   40.000000   62.500000    1.000000
# max     77.000000    1.000000    4.000000   40.000000   99.000000    2.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  199.000000  199.000000  199.000000  199.000000  199.000000  199.000000
# mean     0.733668   33.552764    1.005025    7.914573    2.090452    0.989950
# std      0.684918   20.795687    0.728202    5.020940    1.045365    0.099997
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   14.000000    0.000000    4.000000    1.000000    1.000000
# 50%      1.000000   30.000000    1.000000    9.000000    3.000000    1.000000
# 75%      1.000000   59.000000    2.000000   14.000000    3.000000    1.000000
# max      2.000000   59.000000    2.000000   14.000000    3.000000    1.000000
#
#              thal         num
# count  199.000000  199.000000
# mean     2.748744    1.517588
# std      0.625377    1.222038
# min      0.000000    0.000000
# 25%      3.000000    0.000000
# 50%      3.000000    1.000000
# 75%      3.000000    3.000000
# max      3.000000    4.000000

# %% [markdown]
# Observation

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     44    1   4        17    28    0        1       21      0        1
# 1     60    1   4        18    35    0        1       30      1        6
# 2     55    1   4        24    45    0        1       35      1       10
# 3     66    1   3         5    31    1        2       58      1        5
# 4     66    1   3        10     0    0        1       14      0        0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 194   54    0   4        15    91    1        1       38      0        1
# 195   62    1   1        40     2    0        1       59      2       14
# 196   55    1   4        11    40    1        1        0      0        1
# 197   58    1   4        40    97    1        2       59      2       14
# 198   62    1   2        10    59    0        2       53      1        1
#
#      slope  ca  thal  num
# 0        3   1     3    0
# 1        2   1     3    2
# 2        0   1     3    1
# 3        1   1     3    0
# 4        0   1     3    0
# ..     ...  ..   ...  ...
# 194      3   1     3    1
# 195      3   1     3    0
# 196      3   1     1    2
# 197      3   1     3    0
# 198      3   1     3    1
#
# [199 rows x 14 columns]

# %%
#Let's check the correlation matrix
dfcor = df.corr()
dfcor
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000  0.033837 -0.039809  0.148520  0.074139  0.058483
# sex       0.033837  1.000000  0.037525  0.041280 -0.136759 -0.027732
# cp       -0.039809  0.037525  1.000000 -0.108338  0.101086 -0.047554
# trestbps  0.148520  0.041280 -0.108338  1.000000  0.138332  0.047276
# chol      0.074139 -0.136759  0.101086  0.138332  1.000000  0.069612
# fbs       0.058483 -0.027732 -0.047554  0.047276  0.069612  1.000000
# restecg   0.001487  0.060305  0.033617  0.060275  0.017190  0.116281
# thalach  -0.043703  0.004698 -0.242664  0.536294  0.127242  0.044052
# exang     0.083000  0.041676 -0.082699  0.692578  0.131201 -0.104084
# oldpeak   0.092355  0.102608 -0.193695  0.597693  0.096692 -0.025114
# slope    -0.004302  0.043477 -0.182148  0.403247  0.063839  0.022263
# ca        0.023639 -0.017766 -0.063058  0.042340  0.115919  0.074257
# thal      0.090367  0.023199 -0.089931  0.202020  0.007166 -0.048942
# num       0.286630  0.147190  0.167202  0.090024  0.137947  0.048351
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age       0.001487 -0.043703  0.083000  0.092355 -0.004302  0.023639
# sex       0.060305  0.004698  0.041676  0.102608  0.043477 -0.017766
# cp        0.033617 -0.242664 -0.082699 -0.193695 -0.182148 -0.063058
# trestbps  0.060275  0.536294  0.692578  0.597693  0.403247  0.042340
# chol      0.017190  0.127242  0.131201  0.096692  0.063839  0.115919
# fbs       0.116281  0.044052 -0.104084 -0.025114  0.022263  0.074257
# restecg   1.000000  0.056130 -0.017555 -0.044834  0.125517  0.034462
# thalach   0.056130  1.000000  0.563115  0.543747  0.375447  0.068260
# exang    -0.017555  0.563115  1.000000  0.710123  0.331130  0.000697
# oldpeak  -0.044834  0.543747  0.710123  1.000000  0.200663  0.038518
# slope     0.125517  0.375447  0.331130  0.200663  1.000000  0.008740
# ca        0.034462  0.068260  0.000697  0.038518  0.008740  1.000000
# thal     -0.039106  0.101606  0.235682  0.271392  0.019488  0.040178
# num      -0.033597 -0.132942  0.070843  0.147174 -0.115903  0.084113
#
#               thal       num
# age       0.090367  0.286630
# sex       0.023199  0.147190
# cp       -0.089931  0.167202
# trestbps  0.202020  0.090024
# chol      0.007166  0.137947
# fbs      -0.048942  0.048351
# restecg  -0.039106 -0.033597
# thalach   0.101606 -0.132942
# exang     0.235682  0.070843
# oldpeak   0.271392  0.147174
# slope     0.019488 -0.115903
# ca        0.040178  0.084113
# thal      1.000000  0.111549
# num       0.111549  1.000000

# %%
#Checking correlation with the help of heatmap.
sns.heatmap(dfcor)

# %%
plt.figure(figsize = (25,15))
sns.heatmap(dfcor,cmap = 'Blues',annot = True)

# %%
#num and age is very positively correlated

# %%
collist=df.columns.values
ncol=15
nrows=15

# %%
#Lets visualize outliers through boxplots
plt.figure(figsize=(ncol,5*ncol))
for i in range (1,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
plt.figure(figsize=(20,20))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df[collist[i]])

# %%
#lets check the skewness
df.skew()
# Out:
# age        -0.397178
# sex        -5.537073
# cp         -1.641267
# trestbps   -0.127124
# chol        0.372450
# fbs         0.960949
# restecg     0.396540
# thalach    -0.057023
# exang      -0.007701
# oldpeak    -0.116227
# slope      -0.611222
# ca         -9.898728
# thal       -2.763281
# num         0.302681
# dtype: float64

# %%
#Treating using log
import numpy as np
for col in df.columns:
    if df.skew().loc[col]>0.55:
        df[col] = np.log1p(df[col])

# %%
#lets again check the skewness
df.skew()
# Out:
# age        -0.397178
# sex        -5.537073
# cp         -1.641267
# trestbps   -0.127124
# chol        0.372450
# fbs         0.671074
# restecg     0.396540
# thalach    -0.057023
# exang      -0.007701
# oldpeak    -0.116227
# slope      -0.611222
# ca         -9.898728
# thal       -2.763281
# num         0.302681
# dtype: float64

# %%
#Now treating the outliers
from scipy.stats import zscore
z = np.abs(zscore(df))
z
# Out:
# array([[1.96373685, 0.17631813, 0.62583065, ..., 0.10075854, 0.40278073,
#         1.24498245],
#        [0.08560374, 0.17631813, 0.62583065, ..., 0.10075854, 0.40278073,
#         0.39575601],
#        [0.5548152 , 0.17631813, 0.62583065, ..., 0.10075854, 0.40278073,
#         0.42461322],
#        ...,
#        [0.5548152 , 0.17631813, 0.62583065, ..., 0.10075854, 2.80335388,
#         0.39575601],
#        [0.17056384, 0.17631813, 0.62583065, ..., 0.10075854, 0.40278073,
#         1.24498245],
#        [0.34177131, 0.17631813, 1.89013499, ..., 0.10075854, 0.40278073,
#         0.42461322]])

# %%
threshold = 3
print(np.where(z>3))
# Out:
# (array([ 11,  27,  38,  50,  65,  71,  75,  78,  95,  96, 125, 127, 130,
#        132, 136, 170, 188, 189, 193, 194, 195], dtype=int64), array([12, 11, 11,  1,  2,  2,  2,  1,  0,  2,  1,  1,  2,  2,  2, 12, 12,
#         1, 12,  1,  2], dtype=int64))

# %%
df_new=df[((z<3).all(axis=1))] #Removing the outliers
df_new
# Out:
#      age  sex  cp  trestbps  chol       fbs  restecg  thalach  exang  oldpeak  \
# 0     44    1   4        17    28  0.000000        1       21      0        1
# 1     60    1   4        18    35  0.000000        1       30      1        6
# 2     55    1   4        24    45  0.000000        1       35      1       10
# 3     66    1   3         5    31  0.693147        2       58      1        5
# 4     66    1   3        10     0  0.000000        1       14      0        0
# ..   ...  ...  ..       ...   ...       ...      ...      ...    ...      ...
# 191   53    1   4        25    83  0.693147        1       22      1        6
# 192   62    1   4        32     9  0.000000        1       29      1        1
# 196   55    1   4        11    40  0.693147        1        0      0        1
# 197   58    1   4        40    97  0.693147        2       59      2       14
# 198   62    1   2        10    59  0.000000        2       53      1        1
#
#      slope  ca  thal  num
# 0        3   1     3    0
# 1        2   1     3    2
# 2        0   1     3    1
# 3        1   1     3    0
# 4        0   1     3    0
# ..     ...  ..   ...  ...
# 191      1   1     3    3
# 192      3   1     3    1
# 196      3   1     1    2
# 197      3   1     3    0
# 198      3   1     3    1
#
# [178 rows x 14 columns]

# %%
df.shape
# Out:
# (199, 14)

# %%
df_new.shape
# Out:
# (178, 14)

# %% [markdown]
# Now lets train and test our data. Here our target variable is y i.e num, and our input variables is x

# %%
x=df_new.iloc[:,0:-1]

# %%
df1=x

df1
# Out:
#      age  sex  cp  trestbps  chol       fbs  restecg  thalach  exang  oldpeak  \
# 0     44    1   4        17    28  0.000000        1       21      0        1
# 1     60    1   4        18    35  0.000000        1       30      1        6
# 2     55    1   4        24    45  0.000000        1       35      1       10
# 3     66    1   3         5    31  0.693147        2       58      1        5
# 4     66    1   3        10     0  0.000000        1       14      0        0
# ..   ...  ...  ..       ...   ...       ...      ...      ...    ...      ...
# 191   53    1   4        25    83  0.693147        1       22      1        6
# 192   62    1   4        32     9  0.000000        1       29      1        1
# 196   55    1   4        11    40  0.693147        1        0      0        1
# 197   58    1   4        40    97  0.693147        2       59      2       14
# 198   62    1   2        10    59  0.000000        2       53      1        1
#
#      slope  ca  thal
# 0        3   1     3
# 1        2   1     3
# 2        0   1     3
# 3        1   1     3
# 4        0   1     3
# ..     ...  ..   ...
# 191      1   1     3
# 192      3   1     3
# 196      3   1     1
# 197      3   1     3
# 198      3   1     3
#
# [178 rows x 13 columns]

# %%
y=df_new[['num']]

y
# Out:
#      num
# 0      0
# 1      2
# 2      1
# 3      0
# 4      0
# ..   ...
# 191    3
# 192    1
# 196    2
# 197    0
# 198    1
#
# [178 rows x 1 columns]

# %%
#Scaling the input variable

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

x = scale.fit_transform(x)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.33,random_state=42)

# %%
x_train.shape
# Out:
# (119, 13)

# %%
y_train.shape
# Out:
# (119, 1)

# %%
x_test.shape
# Out:
# (59, 13)

# %%
y_test.shape
# Out:
# (59, 1)

# %%
lr = LogisticRegression()

lr.fit(x_train,y_train)

y_pred_lr = lr.predict(x_test)

# %%
y_pred_lr.shape
# Out:
# (59,)

# %%
score_lr = round(accuracy_score(y_pred_lr,y_test)*100,2)

print("The accuracy score achieved using Logistic Regression is: "+str(score_lr)+" %")
# Out:
# The accuracy score achieved using Logistic Regression is: 35.59 %

# %%
from sklearn import svm

sv = svm.SVC(kernel='linear')

sv.fit(x_train, y_train)

y_pred_svm = sv.predict(x_test)

# %%
score_svm = round(accuracy_score(y_pred_svm,y_test)*100,2)

print("The accuracy score achieved using Linear SVM is: "+str(score_svm)+" %")
# Out:
# The accuracy score achieved using Linear SVM is: 35.59 %

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=7)
knn.fit(x_train,y_train)
y_pred_knn=knn.predict(x_test)

# %%
score_knn = round(accuracy_score(y_pred_knn,y_test)*100,2)

print("The accuracy score achieved using KNN is: "+str(score_knn)+" %")
# Out:
# The accuracy score achieved using KNN is: 32.2 %

# %%
from sklearn.tree import DecisionTreeClassifier

max_accuracy = 0


for x1 in range(200):
    dt = DecisionTreeClassifier(random_state=x1)
    dt.fit(x_train,y_train)
    y_pred_dt = dt.predict(x_test)
    current_accuracy = round(accuracy_score(y_pred_dt,y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x1 = x1
        
#print(max_accuracy)
#print(best_x1)


dt = DecisionTreeClassifier(random_state=best_x1)
dt.fit(x_train,y_train)
y_pred_dt = dt.predict(x_test)

# %%
score_dt = round(accuracy_score(y_pred_dt,y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_dt)+" %")
print(accuracy_score(y_test,y_pred_dt))
print(confusion_matrix(y_test,y_pred_dt))
print(classification_report(y_test,y_pred_dt))
# Out:
# The accuracy score achieved using Decision Tree is: 35.59 %
# 0.3559322033898305
# [[8 5 1 0 0]
#  [3 7 3 1 2]
#  [4 3 2 4 2]
#  [3 2 3 4 0]
#  [0 1 0 1 0]]
#               precision    recall  f1-score   support
#
#            0       0.44      0.57      0.50        14
#            1       0.39      0.44      0.41        16
#            2       0.22      0.13      0.17        15
#            3       0.40      0.33      0.36        12
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.36        59
#    macro avg       0.29      0.30      0.29        59
# weighted avg       0.35      0.36      0.35        59

# %%
from sklearn.ensemble import RandomForestClassifier
max_accuracy = 0


for x2 in range(2000):
    rf = RandomForestClassifier(random_state=x2)
    rf.fit(x_train,y_train)
    y_pred_rf = rf.predict(x_test)
    current_accuracy = round(accuracy_score(y_pred_rf,y_test)*100,2)
    if(current_accuracy>max_accuracy):
        max_accuracy = current_accuracy
        best_x2 = x2
        
#print(max_accuracy)
#print(best_x2)

rf = RandomForestClassifier(random_state=best_x2)
rf.fit(x_train,y_train)
y_pred_rf = rf.predict(x_test)

# %%
score_rf = round(accuracy_score(y_pred_rf,y_test)*100,2)

print("The accuracy score achieved using Decision Tree is: "+str(score_rf)+" %")

print(accuracy_score(y_test,y_pred_rf))
print(confusion_matrix(y_test,y_pred_rf))
print(classification_report(y_test,y_pred_rf))
# Out:
# The accuracy score achieved using Decision Tree is: 45.76 %
# 0.4576271186440678
# [[ 7  5  0  2  0]
#  [ 1 10  3  2  0]
#  [ 1  7  4  3  0]
#  [ 3  2  1  6  0]
#  [ 1  0  0  1  0]]
#               precision    recall  f1-score   support
#
#            0       0.54      0.50      0.52        14
#            1       0.42      0.62      0.50        16
#            2       0.50      0.27      0.35        15
#            3       0.43      0.50      0.46        12
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.46        59
#    macro avg       0.38      0.38      0.37        59
# weighted avg       0.46      0.46      0.44        59

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
rf = RandomForestClassifier()
param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

gd_sr = GridSearchCV(estimator=rf,
                    param_grid=param_grid,
                    scoring='accuracy',cv=5)
gd_sr.fit(x,y)

best_parameters = gd_sr.best_params_
print(best_parameters)
best_result = gd_sr.best_score_
print(best_result)
# Out:
# {'criterion': 'entropy', 'max_depth': 8, 'max_features': 'log2', 'n_estimators': 200}
# 0.33158730158730154

# %%
from sklearn.ensemble import RandomForestClassifier

rf1 = RandomForestClassifier(n_estimators=500,max_features ='sqrt',max_depth = 5,criterion='gini')

rf1.fit(x_train,y_train)
predrf = rf1.predict(x_test)

print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# 0.3728813559322034
# [[ 4  8  0  2  0]
#  [ 2 12  1  1  0]
#  [ 0  8  1  6  0]
#  [ 3  4  0  5  0]
#  [ 1  0  0  1  0]]
#               precision    recall  f1-score   support
#
#            0       0.40      0.29      0.33        14
#            1       0.38      0.75      0.50        16
#            2       0.50      0.07      0.12        15
#            3       0.33      0.42      0.37        12
#            4       0.00      0.00      0.00         2
#
#     accuracy                           0.37        59
#    macro avg       0.32      0.30      0.26        59
# weighted avg       0.39      0.37      0.32        59

# %%
#Cross Validating to avoid overfitting and under fitting of the model.

# %%
from sklearn.model_selection import cross_val_score

score= cross_val_score(rf,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.27777778 0.27777778 0.27777778 0.4        0.25714286]
# 0.2980952380952381
# 0.051575334387262826

# %%
#So we save this model

# %%
import pickle



# Save to file in the current working directory
pkl_filename = "pickle_model.pkl"
with open(pkl_filename, 'wb') as file:
    pickle.dump(rf, file)

# Load from file
with open(pkl_filename, 'rb') as file:
    pickle_model = pickle.load(file)

# %%
import pickle

filename='picklesvcfile.pkl'
pickle.dump(rf, open(filename, 'wb'))

#load the model from disk

loaded_model=pickle.load(open(filename, 'rb'))

loaded_model.predict(x_test)
# Out:
# array([0, 1, 3, 0, 3, 0, 0, 0, 1, 3, 1, 1, 1, 3, 1, 1, 1, 1, 0, 0, 1, 3,
#        0, 1, 3, 3, 2, 2, 3, 1, 3, 1, 3, 1, 1, 1, 0, 1, 3, 3, 1, 1, 1, 2,
#        1, 3, 0, 1, 1, 1, 3, 1, 1, 1, 3, 3, 1, 0, 0], dtype=int64)
